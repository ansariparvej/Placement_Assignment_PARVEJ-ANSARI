# %% [markdown]
# ## Question_7_Solution:

# %% [markdown]
# **Q-7.** Imagine you have a dataset where you need to predict the Genres of Music
# using
# an Unsupervised algorithm and you need to find the accuracy of the model, built-in
# docker, and use some library to display that in frontend
# Dataset This is the Dataset You can use this dataset for this question.

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
# Music features Dataset:
df = pd.read_csv('useful/Q7.csv')
df.head()
# Out:
#          filename       tempo  beats  chroma_stft      rmse
# 0  blues.00081.au  103.359375     50     0.380260  0.248262  \
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
# 2  blues.00031.au  151.999081     75     0.253487  0.151571
# 3  blues.00012.au  184.570312     91     0.269320  0.119072
# 4  blues.00056.au  161.499023     74     0.391059  0.137728
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 0        2116.942959         1956.611056  4196.107960            0.127272  \
# 1        1156.070496         1497.668176  2170.053545            0.058613
# 2        1331.073970         1973.643437  2900.174130            0.042967
# 3        1361.045467         1567.804596  2739.625101            0.069124
# 4        1811.076084         2052.332563  3927.809582            0.075480
#
#         mfcc1  ...     mfcc12     mfcc13    mfcc14    mfcc15    mfcc16
# 0  -26.929785  ...  14.336612 -13.821769  7.562789 -6.181372  0.330165  \
# ...

# %%
df.shape
# Out:
# (1200, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            1200 non-null   object
#  1   tempo               1200 non-null   float64
#  2   beats               1200 non-null   int64
#  3   chroma_stft         1200 non-null   float64
#  4   rmse                1200 non-null   float64
#  5   spectral_centroid   1200 non-null   float64
#  6   spectral_bandwidth  1200 non-null   float64
#  7   rolloff             1200 non-null   float64
#  8   zero_crossing_rate  1200 non-null   float64
#  9   mfcc1               1200 non-null   float64
#  10  mfcc2               1200 non-null   float64
#  11  mfcc3               1200 non-null   float64
#  12  mfcc4               1200 non-null   float64
#  13  mfcc5               1200 non-null   float64
#  14  mfcc6               1200 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['filename', 'tempo', 'beats', 'chroma_stft', 'rmse',
#        'spectral_centroid', 'spectral_bandwidth', 'rolloff',
#        'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
#        'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12',
#        'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19',
#        'mfcc20', 'label'],
#       dtype='object')

# %%
df['label'].unique()
# Out:
# array(['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz',
#        'metal', 'pop', 'reggae', 'rock'], dtype=object)

# %%
# Split X andy:

X = df.drop(['label', 'filename'], axis=1)
y = df['label']
X.shape, y.shape
# Out:
# ((1200, 28), (1200,))

# %%
X.describe().T
# Out:
#                      count         mean          std         min          25%
# tempo               1200.0   119.650771    28.595204   54.978391    99.384014  \
# beats               1200.0    56.882500    14.484769   18.000000    47.000000
# chroma_stft         1200.0     0.370632     0.084014    0.171782     0.304514
# rmse                1200.0     0.129331     0.070874    0.005276     0.079168
# spectral_centroid   1200.0  2203.833135   767.091516  569.930721  1548.496850
# spectral_bandwidth  1200.0  2246.295208   580.235661  897.994319  1815.497242
# rolloff             1200.0  4571.216473  1721.201024  749.062137  3172.968313
# zero_crossing_rate  1200.0     0.103968     0.041925    0.021701     0.070809
# mfcc1               1200.0  -152.721641   111.544452 -552.064063  -217.159272
# mfcc2               1200.0   100.395629    33.575997   -1.527148    74.875960
# mfcc3               1200.0    -8.013423    22.263053  -89.901142   -24.244142
# ...

# %%
for column in X.columns:
    # Extract the minimum and maximum values from the column
    min_value = X[column].min()
    max_value = X[column].max()
    
    # Print the minimum and maximum values for the column
    print("Column:", column)
    print("Min Value:", min_value)
    print("Max Value:", max_value)
    print()
# Out:
# Column: tempo
# Min Value: 54.978390957446805
# Max Value: 234.90767045454547
#
# Column: beats
# Min Value: 18
# Max Value: 117
#
# Column: chroma_stft
# Min Value: 0.171782316163244
# Max Value: 0.6635726746877475
#
# Column: rmse
# Min Value: 0.0052756136283278
# Max Value: 0.3980118632316589
#
# Column: spectral_centroid
# Min Value: 569.9307210492651
# Max Value: 4434.439444257259
#
# Column: spectral_bandwidth
# Min Value: 897.9943189328015
# Max Value: 3509.578677055124
#
# Column: rolloff
# Min Value: 749.0621371904025
# Max Value: 8676.405868294069
#
# Column: zero_crossing_rate
# Min Value: 0.0217005490518575
# Max Value: 0.2748294039038312
#
# Column: mfcc1
# Min Value: -552.0640633094026
# Max Value: 42.03458706710257
#
# Column: mfcc2
# Min Value: -1.527147504301669
# Max Value: 193.09651819234924
#
# Column: mfcc3
# Min Value: -89.90114230950152
# Max Value: 56.66609011353504
#
# Column: mfcc4
# Min Value: -18.76846058738732
# Max Value: 80.69127283002801
#
# ...

# %%
# Column wise unique values:
for col in X:
    print(f'{col}: {X[col].unique()}')
# Out:
# tempo: [103.359375    95.703125   151.99908088 184.5703125  161.49902344
#  107.66601562  92.28515625  58.72691761 117.45383523 172.265625
#  143.5546875  135.99917763  73.828125   129.19921875  67.99958882
#  123.046875    99.38401442  78.30255682  63.02400915 198.76802885
#   86.1328125   71.77734375  83.35433468  69.83741554 112.34714674
#   89.10290948  80.74951172 215.33203125 234.90767045  64.59960938
#   75.99954044  66.25600962  60.09265988  61.5234375   54.97839096]
# beats: [ 50  44  75  91  74  51  80  45  70  26  53  83  66  67  35  54  62  78
#   34  59  79  63  55  81  58  37  49  52  65  61  29  43  96  60  77  38
#   36  28  64  39  92  40  73  71  48  72  41  69  42  24  47  94  76  46
#   18  88  84  56  32  68  22  86  95  57  30 106 117  25  89  31  87  33
#   97  93  82 105 102  90  85 109  98]
# chroma_stft: [0.38026021 0.30645087 0.2534871  0.26932002 0.3910586  0.35658818
#  0.37470972 0.43089413 0.29094843 0.32916273 0.37769044 0.37515819
# ...

# %%
y.unique()
# Out:
# array(['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz',
#        'metal', 'pop', 'reggae', 'rock'], dtype=object)

# %%
# train-test-split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)


# Applying Scaling
scaler = MinMaxScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# Handling missing values
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train_s)
X_test = imputer.transform(X_test_s)


# Training using Unsupervised algorithm:
model = KNeighborsClassifier(n_neighbors=6)
model.fit(X_train, y_train)

# Testing:
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print('Accuracy of model: ', acc*100, '%')
# Out:
# Accuracy of model:  65.41666666666667 %

# %%
# Let's predict:
Input = X_test[50]
y_pred = model.predict([Input])
print("Music Genre ==> ",y_pred[0])
# Out:
# Music Genre ==>  pop
